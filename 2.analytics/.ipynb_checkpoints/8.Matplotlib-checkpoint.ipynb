# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# интерактивный режим
# %matplotlib notebook

x = np.linspace(0, 10, 1000)

plt.plot(x, np.sin(x))

plt.show()

# %%
# настройка габаритов окна
plt.figure(figsize=(8,5)), #facecolor="yellow", frameon=False)

x = np.linspace(0, 10, 1000)

plt.plot(x, np.sin(x))

plt.show()

# %%
plt.figure(figsize=(8,5)), #facecolor="yellow", frameon=False)

x = np.linspace(0, 10, 1000)

plt.plot(x, np.sin(x),label="синусоида")
plt.plot(x, np.cos(x),label="косинусоида")

# настройка легенды
plt.legend(loc="upper right", labelcolor="green", frameon=True)

# сетка
plt.grid(True)

plt.show()

# %% [markdown]
# - Гистограммы

# %%
data = np.random.randint(10, size=50)
data
# Out:
# array([4, 5, 6, 7, 9, 7, 4, 2, 5, 2, 8, 6, 3, 0, 6, 6, 4, 7, 3, 4, 6, 5,
#        6, 9, 9, 2, 9, 9, 2, 3, 4, 4, 0, 8, 5, 6, 6, 5, 3, 6, 8, 8, 3, 8,
#        3, 2, 1, 5, 6, 3])

# %%
plt.hist(data)
plt.show()

# %%
# нормальное (гауссово) распределение
# m = 0, std = 2

data = np.random.randn(1000)

plt.hist(data, bins=50)

plt.show()

# %%
plt.figure(figsize=(8, 6))

m = -1
std = 0.5

data_1 = np.random.normal(-1, 0.5, 1000)
data_2 = np.random.normal(0, 1, 1000)
data_3 = np.random.normal(2, 1.5, 1000)

plt.hist(data_1, bins=100, label="data_1")
plt.hist(data_2, bins=100, alpha=0.5, label="data_2")
n, b, p = plt.hist(data_3, bins=100, alpha=0.5, color="m", label="data_3", lw=2, ec="g")

plt.legend()
plt.text(5, 25, f"mu={m} \nsigma={std}", size="large")
plt.grid(True)

plt.show()

# %%
np.random.seed(0)
np.random.randint(10, size=5)
# Out:
# array([5, 0, 3, 3, 7])
